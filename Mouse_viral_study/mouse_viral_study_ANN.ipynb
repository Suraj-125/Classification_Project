# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv("mouse_viral_study.csv")
df.head()
# Out:
#    Med_1_mL  Med_2_mL  Virus Present
# 0  6.508231  8.582531              0
# 1  4.126116  3.073459              1
# 2  6.427870  6.369758              0
# 3  3.672953  4.905215              1
# 4  1.580321  2.440562              1

# %%
X = df.drop("Virus Present", axis = 1)
y = df["Virus Present"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, mean_absolute_error
from keras.models import Sequential
from keras.layers import Dense

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
def Perceptron():
    model = Sequential()
    model.add(Dense(input_dim = 2, units = 3, activation = "relu", kernel_initializer = "uniform"))
    model.add(Dense(units = 1, kernel_initializer = "uniform", activation = "sigmoid"))
    model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])
    return model

# %%
model = Perceptron()
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5082 - loss: 0.6932
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5120 - loss: 0.6930
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5352 - loss: 0.6930
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5418 - loss: 0.6929
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5664 - loss: 0.6928
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6187 - loss: 0.6924
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5637 - loss: 0.6923
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5975 - loss: 0.6918
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6159 - loss: 0.6917
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6364 - loss: 0.6909
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6764 - loss: 0.6903
# Epoch 12/100
# ...

# %%
x_pred = model.predict(X_train)
x_pred = (x_pred > 0.5)

y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

print("Training Accuracy :", accuracy_score(y_train, x_pred))
print("Testing Accuracy :", accuracy_score(y_test, y_pred))
print("MAE :", mean_absolute_error(y_test, y_pred))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Training Accuracy : 0.99375
# Testing Accuracy : 0.9875
# MAE : 0.0125

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[34,  1],
#        [ 0, 45]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        35
#            1       0.98      1.00      0.99        45
#
#     accuracy                           0.99        80
#    macro avg       0.99      0.99      0.99        80
# weighted avg       0.99      0.99      0.99        80

# %% [markdown]
# # **ANN**

# %%
def ann():
    model = Sequential()
    model.add(Dense(input_dim = 2, units = 3, kernel_initializer = "uniform", activation = "relu"))
    model.add(Dense(units = 3, kernel_initializer = "uniform", activation = "relu"))
    model.add(Dense(units = 1, kernel_initializer = "uniform", activation = "sigmoid"))
    model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])
    return model

# %%
ann_model = ann()
ann_model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5147 - loss: 0.6931
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4980 - loss: 0.6931
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5185 - loss: 0.6930
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5287 - loss: 0.6926
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5495 - loss: 0.6920
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4968 - loss: 0.6920
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5035 - loss: 0.6910
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5112 - loss: 0.6892
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5018 - loss: 0.6875
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4869 - loss: 0.6851
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4948 - loss: 0.6814
# Epoch 12/100
# ...

# %%
x_pred = ann_model.predict(X_train)
x_pred = (x_pred > 0.5)

y_pred = ann_model.predict(X_test)
y_pred = (y_pred > 0.5)

print("Training Accuracy :", accuracy_score(y_train, x_pred))
print("Testing Accuracy :", accuracy_score(y_test, y_pred))
print("MAE :", mean_absolute_error(y_test, y_pred))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Training Accuracy : 0.971875
# Testing Accuracy : 0.975
# MAE : 0.025

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[35,  0],
#        [ 2, 43]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        35
#            1       1.00      0.96      0.98        45
#
#     accuracy                           0.97        80
#    macro avg       0.97      0.98      0.97        80
# weighted avg       0.98      0.97      0.98        80

# %% [markdown]
# - Perceptron model is performing well and providing the acauracy almost 99% without any hyperparameter tuning.
# - By applying hyperparameter tuning, we can get accuracy almost 100% as like Logistic, KNN, SVM.
