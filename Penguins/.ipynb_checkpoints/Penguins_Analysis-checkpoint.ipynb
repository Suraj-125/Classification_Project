# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv("penguins_size.csv")
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# # ***Data Understanding***

# %%
df.shape
# Out:
# (344, 7)

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include = "object")
# Out:
#        species  island   sex
# count      344     344   334
# unique       3       3     3
# top     Adelie  Biscoe  MALE
# freq       152     168   168

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# # ***Data Preprocessing***

# %% [markdown]
# ### **Data Cleaning**

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
# Replacing NaN values with mean and mode

df["culmen_length_mm"].fillna(df["culmen_length_mm"].mean(), inplace = True)
df["culmen_depth_mm"].fillna(df["culmen_depth_mm"].mean(), inplace = True)
df["flipper_length_mm"].fillna(df["flipper_length_mm"].mean(), inplace = True)
df["body_mass_g"].fillna(df["body_mass_g"].mean(), inplace = True)
df["sex"].fillna(df["sex"].mode()[0], inplace = True)
df["sex"].replace({".":df["sex"].mode()[0] }, inplace = True)

# %% [markdown]
# ### **EDA**

# %% [markdown]
# **species**

# %%
df["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df["species"].value_counts().plot(kind = "pie", autopct = "%0.02f%%", shadow = True, explode = [0.1, 0, 0])
plt.show()

# %% [markdown]
# **island**

# %%
df["island"].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
plt.figure(figsize = (8, 4))
df["island"].value_counts().plot(kind = "bar", color = "purple")
plt.show()

# %%
pd.crosstab(df["species"], df["island"], margins = True)
# Out:
# island     Biscoe  Dream  Torgersen  All
# species
# Adelie         44     56         52  152
# Chinstrap       0     68          0   68
# Gentoo        124      0          0  124
# All           168    124         52  344

# %% [markdown]
# **culmen_length_mm**

# %%
sns.barplot(x = df["species"] ,y = df["culmen_length_mm"] )
plt.show()

# %% [markdown]
# **culmen_depth_mm**

# %%
plt.figure(figsize = (8, 4))
sns.barplot(x = df["species"] ,y = df["culmen_depth_mm"] )
plt.show()

# %% [markdown]
# **flipper_length_mm**

# %%
plt.figure(figsize = (8, 4))
sns.barplot(x = df["species"] ,y = df["flipper_length_mm"] )
plt.show()

# %% [markdown]
# **body_mass_g**

# %%
plt.figure(figsize = (8, 4))
sns.barplot(x = df["species"] ,y = df["body_mass_g"] )
plt.show()

# %% [markdown]
# **sex**

# %%
df["sex"].value_counts().plot(kind = "pie", autopct = "%0.02f%%", shadow = True)
plt.show()

# %%
plt.figure(figsize = (8, 4))
sns.scatterplot(x = df["culmen_depth_mm"] ,y = df["flipper_length_mm"], hue = df["sex"])
plt.show()

# %%
pd.crosstab(df["sex"], df["species"], margins = True)
# Out:
# species  Adelie  Chinstrap  Gentoo  All
# sex
# FEMALE       73         34      58  165
# MALE         79         34      66  179
# All         152         68     124  344

# %%
pd.crosstab(df["sex"], df["island"], margins = True)
# Out:
# island  Biscoe  Dream  Torgersen  All
# sex
# FEMALE      80     61         24  165
# MALE        88     63         28  179
# All        168    124         52  344

# %%
corr = df.drop(["island", "species", "sex"], axis = 1).corr()
corr
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %% [markdown]
# ### **Data Wrangling**

# %% [markdown]
# **Feature Transformation**

# %%
df.drop(["island", "species", "sex"], axis = 1).skew()
# Out:
# culmen_length_mm     0.053272
# culmen_depth_mm     -0.143880
# flipper_length_mm    0.346682
# body_mass_g          0.471690
# dtype: float64

# %%
df.to_csv("penguins_analyzed.csv", index = False)
